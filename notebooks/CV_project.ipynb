# %%
import requests
from PIL import Image
from io import BytesIO
import cv2
from ultralytics import YOLO
import numpy as np
import streamlit as st
import torch
import urllib.request
import os
import gc

# %%
# %%writefile data1.yaml
# # Пути к папкам датасета (на Kaggle они будут вести в /kaggle/input/...)
# train: C:/datasets/Face-Detection/images/train
# val: C:/datasets/Face-Detection/images/val
#
# nc: 1
# names:
#   0: face
#
# # Количество классов
# nc: 1
#
# # Имена классов
# names:
#   0: face
# Out:
# Writing data1.yaml

# %%
import torch
print("CUDA доступна:", torch.cuda.is_available())
print("Название карты:", torch.cuda.get_device_name(0))
# Out:
# CUDA доступна: True
# Название карты: NVIDIA GeForce RTX 3050 Ti Laptop GPU

# %%
gc.collect()
torch.cuda.empty_cache()

# %%
# Инициализируем легкую модель YOLOv11 (nano)
model = YOLO("yolo11n.pt")

# Запуск обучения
results = model.train(
    data="data1.yaml",   # Путь к конфигу (так как ноутбук лежит в папке notebooks/)
    epochs=10,             # 50 эпох по ТЗ
    batch=16,               # ВАЖНО: 8 или 16, чтобы уложиться в 4 ГБ видеопамяти
    imgsz=640,             # Базовый размер картинок
    device=0,              # Твоя RTX 3050 Ti, которую мы только что оживили!
    workers=2              # Чтобы ноутбук не зависал намертво во время вычислений
)
# Out:
# Ultralytics 8.4.60  Python-3.13.5 torch-2.12.0+cu132 CUDA:0 (NVIDIA GeForce RTX 3050 Ti Laptop GPU, 4096MiB)
# ...
